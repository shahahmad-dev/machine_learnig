# %%
import math

# %%
# Example dataset
n_A = 4 
n_B = 6
total = n_A + n_B

# %%
# let's calculate the proportions
prop_A = n_A / total
prop_B = n_B / total

# print proportions
print(f"Proportion of A: {prop_A}")
print(f"Proportion of B: {prop_B}")
# Out:
# Proportion of A: 0.4
# Proportion of B: 0.6
